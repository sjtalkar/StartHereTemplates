# %% [markdown]
#  <h1><center> Animation</center></h1>
#
# <li >Things to make sure the animation performs
#     <li> For FuncAnimation to work you have to place this magic
#     <li> You also should invoke plt.show()
#     <li> The callback function MUST have a loop/frame counter argument

# %%
# %matplotlib notebook

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.animation as animation

# %%
fig, ax = plt.subplots(nrows=1, ncols=1,figsize=(7, 7))
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
def drawPict(loop_count):
    df = pd.DataFrame({'X':np.random.randint(1, 11, 10), 'Y': np.random.randint(1, 11, 10)})
    plt.gca().clear()
    plt.plot(df['X'], df['Y'])  
    if loop_count == 10:
        animation.event_source.stop()

# %%
myAnim = animation.FuncAnimation(plt.gcf(), drawPict, interval=10)
plt.show()

# %%
fig, ax= plt.subplots (nrows=1, ncols=1, figsize=(10, 10))
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# ## Animation with Start and Stop toggle upon click

# %%
def toggleAnimation():
    animation_flag = True

    def onClick(event):
        nonlocal animation_flag
        
        if animation_flag:
            anim.event_source.stop()
            animation_flag = False
        else:
            anim.event_source.start()
            animation_flag = True
    def calc ():
        from numpy.random import rand
        n = 5
        df = pd.DataFrame (rand (n, 2), columns = ['sell', 'buy'])
        return df ['sell'], df ['buy']
    
    def plot (loop_count):
        plt.cla ()
        df_sell, df_buy = calc ()
        show = pd.concat ([df_buy, df_sell], axis = 1)
        show.plot.bar (ax = ax)
   

    fig.canvas.mpl_connect('button_press_event', onClick)

    anim = animation.FuncAnimation (fig, plot, interval = 1000)
    plt.show()
    

toggleAnimation()

# %%
df = pd.read_csv(r'https://pythonprogramming.net/yahoo_finance_replacement')
print(df.shape)
print(df.info())
# Out:
# (4419, 7)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4419 entries, 0 to 4418
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            4419 non-null   object
#  1   Open            4419 non-null   float64
#  2   High            4419 non-null   float64
#  3   Low             4419 non-null   float64
#  4   Close           4419 non-null   float64
#  5   Adjusted_close  4419 non-null   float64
#  6   Volume          4419 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 241.8+ KB
# None

# %%
df.head()
# Out:
#          Date    Open    High     Low   Close  Adjusted_close      Volume
# 0  2017-07-26  153.35  153.93  153.06  153.50          153.50  12778195.0
# 1  2017-07-25  151.80  153.84  151.80  152.74          152.74  18714400.0
# 2  2017-07-24  150.58  152.44  149.90  152.09          152.09  21304700.0
# 3  2017-07-21  149.99  150.44  148.88  150.27          150.27  26252630.0
# 4  2017-07-20  151.50  151.74  150.19  150.34          150.34  17243748.0
